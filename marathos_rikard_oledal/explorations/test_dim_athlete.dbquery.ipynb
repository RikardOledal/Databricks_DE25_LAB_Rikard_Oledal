-- %%
SELECT DISTINCT
    athlete_id,
    athlete_gender,
    athlete_country AS athlete_country_code,
    athlete_country_name,
    athlete_year_of_birth AS athlete_birth_year
FROM
    marathos.silver.marathon_obt;
